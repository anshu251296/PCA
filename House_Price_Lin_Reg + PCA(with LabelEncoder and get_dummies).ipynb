# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('houseprice.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
df.shape
# Out:
# (1460, 81)

# %%
df['Id'].nunique()
# Out:
# 1460

# %%
df.drop('Id',axis=1,inplace=True)
df.shape
# Out:
# (1460, 80)

# %%
nv = df.isnull().sum()
nv[nv>0]
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
df.drop(['PoolQC','Alley','MiscFeature'],axis=1,inplace=True)
nv = df.isnull().sum()
nv[nv>0]
# Out:
# LotFrontage      259
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# Fence           1179
# dtype: int64

# %%
cat_nan = [i for i in df.columns if df[i].isnull().sum()>0 and df[i].dtypes=='object']
num_nan = [i for i in df.columns if df[i].isnull().sum()>0 and df[i].dtypes!='object']
print(cat_nan)
print(len(cat_nan))
print(num_nan)
print(len(num_nan))
# Out:
# ['MasVnrType', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Electrical', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'Fence']
# 13
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']
# 3

# %% [markdown]
# #### Basement null value Handling

# %%
bs_cols = ['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2']
for i in bs_cols:
    df[i].fillna('No_Base',inplace=True)
nv = df.isnull().sum()
nv[nv>0]
# Out:
# LotFrontage      259
# MasVnrType         8
# MasVnrArea         8
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# Fence           1179
# dtype: int64

# %%
gar_cols = ['GarageType', 'GarageFinish', 'GarageQual', 'GarageCond']
for i in gar_cols:
    df[i].fillna('No_Garage',inplace=True)
nv = df.isnull().sum()
nv[nv>0]
# Out:
# LotFrontage     259
# MasVnrType        8
# MasVnrArea        8
# Electrical        1
# FireplaceQu     690
# GarageYrBlt      81
# Fence          1179
# dtype: int64

# %%
for i in ['LotFrontage','MasVnrArea']:
    df[i].fillna(df[i].mean(),inplace=True)
nv = df.isnull().sum()
nv[nv>0]
# Out:
# MasVnrType        8
# Electrical        1
# FireplaceQu     690
# GarageYrBlt      81
# Fence          1179
# dtype: int64

# %%
nv = df.isnull().sum()
nv[nv>0]
# Out:
# MasVnrType        8
# Electrical        1
# FireplaceQu     690
# GarageYrBlt      81
# Fence          1179
# dtype: int64

# %%
for i in nv[nv>0].index:
    print(df[i].value_counts())
# Out:
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: Electrical, dtype: int64
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: FireplaceQu, dtype: int64
# 2005.0    65
# 2006.0    59
# 2004.0    53
# 2003.0    50
# 2007.0    49
#           ..
# 1906.0     1
# 1908.0     1
# 1933.0     1
# 1900.0     1
# 1927.0     1
# Name: GarageYrBlt, Length: 97, dtype: int64
# MnPrv    157
# GdPrv     59
# GdWo      54
# MnWw      11
# Name: Fence, dtype: int64

# %%
nv[nv>0].index
# Out:
# Index(['MasVnrType', 'Electrical', 'FireplaceQu', 'GarageYrBlt', 'Fence'], dtype='object')

# %%
for i in ['MasVnrType', 'Electrical', 'FireplaceQu', 'Fence']:
    x = df[i].mode().max()
    df[i].fillna(x,inplace=True)

# %%
nv = df.isnull().sum()
nv[nv>0]
# Out:
# GarageYrBlt    81
# dtype: int64

# %%
df['GarageYrBlt'].fillna(2005.0,inplace=True)
nv = df.isnull().sum()
nv[nv>0]
# Out:
# Series([], dtype: int64)

# %%
df.shape
# Out:
# (1460, 77)

# %% [markdown]
# ### Outlier Handling

# %%
df.describe(percentiles=[0.97,0.98,0.99]).T
# Out:
#                 count           mean           std      min            50%  \
# MSSubClass     1460.0      56.897260     42.300571     20.0      50.000000
# LotFrontage    1460.0      70.049958     22.024023     21.0      70.049958
# LotArea        1460.0   10516.828082   9981.264932   1300.0    9478.500000
# OverallQual    1460.0       6.099315      1.382997      1.0       6.000000
# OverallCond    1460.0       5.575342      1.112799      1.0       5.000000
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1973.000000
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1994.000000
# MasVnrArea     1460.0     103.685262    180.569112      0.0       0.000000
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0     383.500000
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.000000
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     477.500000
# TotalBsmtSF    1460.0    1057.429452    438.705324      0.0     991.500000
# 1stFlrSF       1460.0    1162.626712    386.587738    334.0    1087.000000
# 2ndFlrSF       1460.0     346.992466    436.528436      0.0       0.000000
# LowQualFinSF   1460.0       5.844521     48.623081      0.0       0.000000
# GrLivArea      1460.0    1515.463699    525.480383    334.0    1464.000000
# BsmtFullBath   1460.0       0.425342      0.518911      0.0       0.000000
# BsmtHalfBath   1460.0       0.057534      0.238753      0.0       0.000000
# FullBath       1460.0       1.565068      0.550916      0.0       2.000000
# HalfBath       1460.0       0.382877      0.502885      0.0       0.000000
# BedroomAbvGr   1460.0       2.866438      0.815778      0.0       3.000000
# KitchenAbvGr   1460.0       1.046575      0.220338      0.0       1.000000
# TotRmsAbvGrd   1460.0       6.517808      1.625393      2.0       6.000000
# Fireplaces     1460.0       0.613014      0.644666      0.0       1.000000
# GarageYrBlt    1460.0    1979.976027     24.749688   1900.0    1984.500000
# GarageCars     1460.0       1.767123      0.747315      0.0       2.000000
# GarageArea     1460.0     472.980137    213.804841      0.0     480.000000
# WoodDeckSF     1460.0      94.244521    125.338794      0.0       0.000000
# OpenPorchSF    1460.0      46.660274     66.256028      0.0      25.000000
# EnclosedPorch  1460.0      21.954110     61.119149      0.0       0.000000
# 3SsnPorch      1460.0       3.409589     29.317331      0.0       0.000000
# ScreenPorch    1460.0      15.060959     55.757415      0.0       0.000000
# PoolArea       1460.0       2.758904     40.177307      0.0       0.000000
# MiscVal        1460.0      43.489041    496.123024      0.0       0.000000
# MoSold         1460.0       6.321918      2.703626      1.0       6.000000
# YrSold         1460.0    2007.815753      1.328095   2006.0    2008.000000
# SalePrice      1460.0  180921.195890  79442.502883  34900.0  163000.000000
#
#                      97%        98%        99%       max
# MSSubClass        160.00     188.20     190.00     190.0
# LotFrontage       114.00     120.82     137.41     313.0
# LotArea         21571.80   25251.62   37567.64  215245.0
# OverallQual         9.00       9.00      10.00      10.0
# OverallCond         8.00       8.00       9.00       9.0
# YearBuilt        2007.00    2008.00    2009.00    2010.0
# YearRemodAdd     2008.00    2008.00    2009.00    2010.0
# MasVnrArea        573.69     650.82     791.28    1600.0
# BsmtFinSF1       1375.99    1442.64    1572.41    5644.0
# BsmtFinSF2        546.23     658.12     830.38    1474.0
# BsmtUnfSF        1589.38    1678.20    1797.05    2336.0
# TotalBsmtSF      1905.46    2001.64    2155.05    6110.0
# 1stFlrSF         1981.61    2072.28    2219.46    4692.0
# 2ndFlrSF         1245.53    1318.56    1418.92    2065.0
# LowQualFinSF        0.00       0.00     360.00     572.0
# GrLivArea        2633.23    2782.38    3123.48    5642.0
# BsmtFullBath        1.00       1.00       2.00       3.0
# BsmtHalfBath        1.00       1.00       1.00       2.0
# FullBath            2.00       3.00       3.00       3.0
# HalfBath            1.00       1.00       1.00       2.0
# BedroomAbvGr        4.00       4.00       5.00       8.0
# KitchenAbvGr        2.00       2.00       2.00       3.0
# TotRmsAbvGrd       10.00      10.82      11.00      14.0
# Fireplaces          2.00       2.00       2.00       3.0
# GarageYrBlt      2008.00    2008.00    2009.00    2010.0
# GarageCars          3.00       3.00       3.00       4.0
# GarageArea        884.00     907.46    1002.79    1418.0
# WoodDeckSF        385.38     430.10     505.46     857.0
# OpenPorchSF       213.23     240.82     285.82     547.0
# EnclosedPorch     216.00     235.64     261.05     552.0
# 3SsnPorch           0.00       0.00     168.00     508.0
# ScreenPorch       192.00     223.64     268.05     480.0
# PoolArea            0.00       0.00       0.00     738.0
# MiscVal           400.00     500.00     700.00   15500.0
# MoSold             12.00      12.00      12.00      12.0
# YrSold           2010.00    2010.00    2010.00    2010.0
# SalePrice      374230.00  394931.06  442567.01  755000.0

# %%
df.describe(percentiles=[0.97,0.98,0.99]).T.index
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
out_cols_98 = ['LotFrontage','LotArea','MasVnrArea','BsmtFinSF1','BsmtFinSF2',
               'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
              'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'HalfBath',
              'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
               'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
              'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
               'SalePrice']
print(out_cols_98)
# Out:
# ['LotFrontage', 'LotArea', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'SalePrice']

# %%
def oh1(x):
    x = x.clip(upper=x.quantile(0.98))
    return x

# %%
df[out_cols_98] = df[out_cols_98].apply(oh1)

# %%
df.describe(percentiles=[0.01,0.02,0.03,0.05]).T
# Out:
#                 count           mean           std      min        1%  \
# MSSubClass     1460.0      56.897260     42.300571     20.0     20.00
# LotFrontage    1460.0      69.405164     18.845067     21.0     21.00
# LotArea        1460.0    9884.318219   4269.103743   1300.0   1680.00
# OverallQual    1460.0       6.099315      1.382997      1.0      3.00
# OverallCond    1460.0       5.575342      1.112799      1.0      3.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0   1899.18
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0   1950.00
# MasVnrArea     1460.0      99.054851    159.552455      0.0      0.00
# BsmtFinSF1     1460.0     436.678219    424.424497      0.0      0.00
# BsmtFinSF2     1460.0      41.938082    136.258146      0.0      0.00
# BsmtUnfSF      1460.0     563.631507    431.331047      0.0      0.00
# TotalBsmtSF    1460.0    1048.256986    398.396991      0.0      0.00
# 1stFlrSF       1460.0    1155.655068    358.974939    334.0    520.00
# 2ndFlrSF       1460.0     343.673151    427.613429      0.0      0.00
# LowQualFinSF   1460.0       0.000000      0.000000      0.0      0.00
# GrLivArea      1460.0    1504.468767    483.292715    334.0    692.18
# BsmtFullBath   1460.0       0.413699      0.492665      0.0      0.00
# BsmtHalfBath   1460.0       0.056164      0.230318      0.0      0.00
# FullBath       1460.0       1.565068      0.550916      0.0      1.00
# HalfBath       1460.0       0.374658      0.484200      0.0      0.00
# BedroomAbvGr   1460.0       2.839726      0.748082      0.0      1.00
# KitchenAbvGr   1460.0       1.045205      0.211098      0.0      1.00
# TotRmsAbvGrd   1460.0       6.504521      1.584136      2.0      3.00
# Fireplaces     1460.0       0.609589      0.634547      0.0      0.00
# GarageYrBlt    1460.0    1979.976027     24.749688   1900.0   1917.18
# GarageCars     1460.0       1.763699      0.739318      0.0      0.00
# GarageArea     1460.0     470.137534    205.938812      0.0      0.00
# WoodDeckSF     1460.0      92.019178    117.263208      0.0      0.00
# OpenPorchSF    1460.0      45.170959     59.666175      0.0      0.00
# EnclosedPorch  1460.0      21.067260     56.943392      0.0      0.00
# 3SsnPorch      1460.0       0.000000      0.000000      0.0      0.00
# ScreenPorch    1460.0      13.677534     48.367922      0.0      0.00
# PoolArea       1460.0       0.000000      0.000000      0.0      0.00
# MiscVal        1460.0      16.482192     86.867615      0.0      0.00
# MoSold         1460.0       6.321918      2.703626      1.0      1.00
# YrSold         1460.0    2007.815753      1.328095   2006.0   2006.00
# SalePrice      1460.0  179093.495753  71929.291417  34900.0  61815.97
#
#                      2%        3%        5%            50%        max
# MSSubClass        20.00     20.00     20.00      50.000000     190.00
# LotFrontage       24.00     30.00     35.95      70.049958     120.82
# LotArea         2124.74   2522.00   3311.70    9478.500000   25251.62
# OverallQual        4.00      4.00      4.00       6.000000      10.00
# OverallCond        3.00      4.00      4.00       5.000000       9.00
# YearBuilt       1908.36   1910.00   1916.00    1973.000000    2010.00
# YearRemodAdd    1950.00   1950.00   1950.00    1994.000000    2010.00
# MasVnrArea         0.00      0.00      0.00       0.000000     650.82
# BsmtFinSF1         0.00      0.00      0.00     383.500000    1442.64
# BsmtFinSF2         0.00      0.00      0.00       0.000000     658.12
# BsmtUnfSF          0.00      0.00      0.00     477.500000    1678.20
# TotalBsmtSF        0.00    312.33    519.30     991.500000    2001.64
# 1stFlrSF         583.70    625.00    672.95    1087.000000    2072.28
# 2ndFlrSF           0.00      0.00      0.00       0.000000    1318.56
# LowQualFinSF       0.00      0.00      0.00       0.000000       0.00
# GrLivArea        768.00    796.00    848.00    1464.000000    2782.38
# BsmtFullBath       0.00      0.00      0.00       0.000000       1.00
# BsmtHalfBath       0.00      0.00      0.00       0.000000       1.00
# FullBath           1.00      1.00      1.00       2.000000       3.00
# HalfBath           0.00      0.00      0.00       0.000000       1.00
# BedroomAbvGr       1.00      1.00      2.00       3.000000       4.00
# KitchenAbvGr       1.00      1.00      1.00       1.000000       2.00
# TotRmsAbvGrd       4.00      4.00      4.00       6.000000      10.82
# Fireplaces         0.00      0.00      0.00       1.000000       2.00
# GarageYrBlt     1920.00   1924.00   1930.00    1984.500000    2010.00
# GarageCars         0.00      0.00      0.00       2.000000       3.00
# GarageArea         0.00      0.00      0.00     480.000000     907.46
# WoodDeckSF         0.00      0.00      0.00       0.000000     430.10
# OpenPorchSF        0.00      0.00      0.00      25.000000     240.82
# EnclosedPorch      0.00      0.00      0.00       0.000000     235.64
# 3SsnPorch          0.00      0.00      0.00       0.000000       0.00
# ScreenPorch        0.00      0.00      0.00       0.000000     223.64
# PoolArea           0.00      0.00      0.00       0.000000       0.00
# MiscVal            0.00      0.00      0.00       0.000000     500.00
# MoSold             1.00      1.00      2.00       6.000000      12.00
# YrSold          2006.00   2006.00   2006.00    2008.000000    2010.00
# SalePrice      79000.00  82000.00  88000.00  163000.000000  394931.06

# %%
out_cols_01 = ['LotArea', 'OverallQual', 'OverallCond','1stFlrSF','TotRmsAbvGrd',
                'GrLivArea','SalePrice']
print(out_cols_01)
# Out:
# ['LotArea', 'OverallQual', 'OverallCond', '1stFlrSF', 'TotRmsAbvGrd', 'GrLivArea', 'SalePrice']

# %%
def oh2(x):
    x = x.clip(lower=x.quantile(0.01))
    return x

# %%
df[out_cols_01] = df[out_cols_01].apply(oh2)

# %%
df.shape
# Out:
# (1460, 77)

# %%
df1 = df.copy()
df1.shape
# Out:
# (1460, 77)

# %%
df.to_csv('hprice_after_preprocess.csv')

# %%
cat_cols = [i for i in df.columns if df[i].dtypes=='object']
print(len(cat_cols))
# Out:
# 40

# %% [markdown]
# ### Approach -1 Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
for i in cat_cols:
    df1[i] = lb.fit_transform(df1[i])
df1.dtypes.value_counts()
# Out:
# int32      40
# int64      19
# float64    18
# dtype: int64

# %%
x = df1.drop('SalePrice',axis=1)
y = df1['SalePrice']
print(x.shape)
print(y.shape)
# Out:
# (1460, 76)
# (1460,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=42)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1095, 76)
# (365, 76)
# (1095,)
# (365,)

# %%
from sklearn.linear_model import LinearRegression

# %%
m1 = LinearRegression()
m1.fit(x_train,y_train)
print('Training_score',m1.score(x_train,y_train))
print('Testing_score',m1.score(x_test,y_test))
# Out:
# Training_score 0.8911145142398861
# Testing_score 0.8924731252870297

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
x_train_sc = sc.fit_transform(x_train) 
x_test_sc = sc.transform(x_test)

# %%
m2 = LinearRegression()
m2.fit(x_train_sc,y_train)
print('Training_score',m2.score(x_train_sc,y_train))
print('Testing_score',m2.score(x_test_sc,y_test))
# Out:
# Training_score 0.8911140277094899
# Testing_score 0.8923961051508513

# %% [markdown]
# ### PCA

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA()
pc_x_train = pca.fit_transform(x_train_sc)
pc_x_test = pca.transform(x_test_sc)
print(pc_x_train.shape)
print(pc_x_test.shape)
# Out:
# (1095, 76)
# (365, 76)

# %%
eig_val = pd.DataFrame({'Var':pca.explained_variance_})
eig_val.head()
# Out:
#          Var
# 0  10.397402
# 1   4.193391
# 2   3.853379
# 3   3.012935
# 4   2.438278

# %%
eig_val['Contri'] = eig_val['Var']*100/eig_val['Var'].sum()
eig_val['CumSum'] = eig_val['Contri'].cumsum()
eig_val.head()
# Out:
#          Var     Contri     CumSum
# 0  10.397402  14.230009  14.230009
# 1   4.193391   5.739126  19.969135
# 2   3.853379   5.273780  25.242916
# 3   3.012935   4.123539  29.366455
# 4   2.438278   3.337056  32.703511

# %%
eig_val[eig_val['CumSum']<80].tail(7)
# Out:
#          Var    Contri     CumSum
# 27  0.872549  1.194181  73.148644
# 28  0.850739  1.164332  74.312976
# 29  0.839748  1.149289  75.462266
# 30  0.816632  1.117653  76.579919
# 31  0.793977  1.086646  77.666565
# 32  0.777824  1.064539  78.731104
# 33  0.771025  1.055234  79.786338

# %%
pc_train = pd.DataFrame(pc_x_train)
pc_train = pc_train.iloc[:,:30]
print(pc_train.shape)
pc_train.head()
# Out:
# (1095, 30)
#          0         1         2         3         4         5         6   \
# 0  1.775512 -1.120963 -3.899236 -0.942014  0.480689 -1.150501  1.178268
# 1 -0.277394 -2.438229  2.847089  1.369318 -0.042831  0.013838  1.215967
# 2 -4.436284  0.226880 -0.540933 -1.072174 -1.467458  0.506372 -0.216647
# 3 -1.940067  0.546740  1.714690 -1.309590 -2.353330 -0.328687  0.293791
# 4 -1.734926  0.615985  1.756388 -0.655103 -1.487885 -2.519024 -0.710291
#
#          7         8         9   ...        20        21        22        23  \
# 0 -2.797053  0.308599  1.360914  ... -0.698774 -0.112402 -0.841262  0.613597
# 1  1.086225 -2.129894  0.699209  ... -0.112301  0.309470 -0.198502  1.303387
# 2 -1.070789 -0.123326 -1.263389  ... -0.031833  0.164746 -0.128344  0.113619
# 3 -1.738255  0.847541  0.133178  ...  2.606353  0.864105 -1.624376  0.905932
# 4  0.816704 -0.496037  0.657277  ...  2.841511 -0.524341 -1.740184  2.006901
#
#          24        25        26        27        28        29
# 0  0.321200 -0.904277 -0.117512  0.581248 -0.560278 -0.670137
# 1  0.977496  0.107450  1.286202  1.620570 -1.011773  0.157493
# 2 -0.431887  0.921287 -0.961610 -0.083733  0.971113  0.399954
# 3 -0.509500  1.383277  1.260139 -0.514489 -0.226077 -0.236176
# 4  0.529890 -3.200090 -1.753232 -1.323015  0.400313 -1.629678
#
# [5 rows x 30 columns]

# %%
pc_test = pd.DataFrame(pc_x_test)
pc_test = pc_test.iloc[:,:30]
print(pc_test.shape)
pc_test.head()
# Out:
# (365, 30)
#          0         1         2         3         4         5         6   \
# 0 -2.253183 -1.755739  1.398885  0.214591 -1.095537 -1.050384 -0.439589
# 1  5.433615  0.819641  1.784858  2.359093  1.044885 -0.019221 -1.651985
# 2 -4.293985  0.377564  0.140636 -2.743291 -1.672841 -0.702767  0.163140
# 3 -2.459562  0.715935  1.163336  0.580733 -0.482541 -1.014272 -1.096407
# 4  5.527602 -2.233682  0.172885 -3.353039  2.260897  1.343908 -0.249103
#
#          7         8         9   ...        20        21        22        23  \
# 0  0.200878 -1.814528  1.145812  ...  0.636903 -1.231758  1.157171 -1.761325
# 1  0.553032  0.321985  0.187745  ... -0.609591 -0.577769  0.575049 -0.459922
# 2 -1.402150 -0.776163 -1.182737  ... -1.144395 -0.739518  1.177116 -0.550151
# 3 -1.371946 -1.599506  0.032905  ... -1.109246  0.010694 -0.199266  1.059216
# 4  0.592315 -0.697571 -1.423487  ... -0.397284  0.182560  0.210254 -0.120837
#
#          24        25        26        27        28        29
# 0  0.575905  0.101150  0.275057  1.100106 -1.119435  1.386336
# 1  0.075502  0.013124 -0.187036 -0.253041  0.605781 -0.042986
# 2  0.751055 -0.156152 -0.094310  1.082695  0.884629 -0.796851
# 3 -0.750213 -1.615768 -0.396103  0.933636 -1.214415 -0.009670
# 4 -0.787927  1.698902 -0.177744  0.443724  0.671456 -0.409809
#
# [5 rows x 30 columns]

# %%
print(pc_train.shape)
print(pc_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1095, 30)
# (365, 30)
# (1095,)
# (365,)

# %%
m3 = LinearRegression()
m3.fit(pc_train,y_train)
print('Training_score',m3.score(pc_train,y_train))
print('Testing_score',m3.score(pc_test,y_test))
# Out:
# Training_score 0.8660192236561031
# Testing_score 0.8985840149911961

# %%
ypred_m3 = m3.predict(pc_test)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
def gen_matrix(ytest,ypred):
    mae = mean_absolute_error(ytest,ypred)
    mse = mean_squared_error(ytest,ypred)
    rmse = np.sqrt(mean_squared_error(ytest,ypred))
    r2s = r2_score(ytest,ypred)
    print('MAE',mae)
    print('MSE',mse)
    print('RMSE',rmse)
    print('R2_score',r2s)

# %%
gen_matrix(y_test,ypred_m3)
# Out:
# MAE 17094.59910322012
# MSE 536435890.6688689
# RMSE 23161.085697109902
# R2_score 0.8985840149911961

# %% [markdown]
# ### Approach - 2 Get_Dummies

# %%
cat_cols = [i for i in df.columns if df[i].dtypes=='object']
print(len(cat_cols))
print(cat_cols)
# Out:
# 40
# ['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'Fence', 'SaleType', 'SaleCondition']

# %%
df1 = pd.get_dummies(data=df,columns=cat_cols,drop_first=True)
df1.shape
# Out:
# (1460, 249)

# %%
x1 = df1.drop('SalePrice',axis=1)
y1 = df1['SalePrice']
print(x1.shape)
print(y1.shape)
# Out:
# (1460, 248)
# (1460,)

# %%
from sklearn.model_selection import train_test_split
x_train1,x_test1,y_train1,y_test1 = train_test_split(x1,y1,test_size=0.25,random_state=10)
print(x_train1.shape)
print(x_test1.shape)
print(y_train1.shape)
print(y_test1.shape)
# Out:
# (1095, 248)
# (365, 248)
# (1095,)
# (365,)

# %%
m4 = LinearRegression()
m4.fit(x_train1,y_train1)
print('Training_score',m4.score(x_train1,y_train1))
print('Testing_score',m4.score(x_test1,y_test1))
# overfit model
# Out:
# Training_score 0.9450224851961514
# Testing_score 0.7849927974463277

# %% [markdown]
# ### PCA

# %%
sc1 = StandardScaler()
x_train_sc1 = sc1.fit_transform(x_train1) 
x_test_sc1 = sc1.transform(x_test1)

# %%
pca1 = PCA()
x_train_pc1 = pca1.fit_transform(x_train_sc1)
x_test_pc1 = pca1.transform(x_test_sc1)
print(x_train_pc1.shape)
print(x_test_pc1.shape)
# Out:
# (1095, 248)
# (365, 248)

# %%
eig_val1 = pd.DataFrame({'Var':pca1.explained_variance_})
eig_val1.head()
# Out:
#          Var
# 0  16.922308
# 1   8.051164
# 2   7.072466
# 3   6.034808
# 4   5.677673

# %%
eig_val1['Contri'] = eig_val1['Var']*100/eig_val1['Var'].sum()
eig_val1.head()
# Out:
#          Var    Contri
# 0  16.922308  7.103720
# 1   8.051164  3.379753
# 2   7.072466  2.968911
# 3   6.034808  2.533318
# 4   5.677673  2.383398

# %%
eig_val1['CumSum'] = eig_val1['Contri'].cumsum()
eig_val1.tail()
# Out:
#               Var        Contri  CumSum
# 243  6.705258e-32  2.814762e-32   100.0
# 244  6.705258e-32  2.814762e-32   100.0
# 245  6.705258e-32  2.814762e-32   100.0
# 246  6.705258e-32  2.814762e-32   100.0
# 247  6.705258e-32  2.814762e-32   100.0

# %%
eig_val1[eig_val1['CumSum']<76].tail()
# Out:
#          Var    Contri     CumSum
# 76  1.067135  0.447966  73.989097
# 77  1.044976  0.438664  74.427761
# 78  1.031283  0.432916  74.860678
# 79  1.011247  0.424506  75.285184
# 80  1.007534  0.422947  75.708130

# %%
train_res_df = pd.DataFrame(x_train_pc1)
train_res_df.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0 -4.622960  1.161616 -0.252797 -1.672862  0.419907  0.980594 -2.242490
# 1  3.460182  3.193334 -1.538067  4.954354 -2.296506  0.362510  1.131920
# 2 -3.727533  0.948955 -0.117145  0.794336 -1.013626 -2.305109  0.072100
# 3 -2.256559  0.127604  0.189685 -0.391265 -0.363494 -3.290996  3.478400
# 4  0.161543 -5.091692  1.469638 -1.366211  0.164836 -1.560062 -1.082986
#
#         7         8         9    ...           238           239  \
# 0  0.237645  0.396260 -1.035301  ... -1.226720e-16 -3.482708e-16
# 1 -1.122479 -0.440176  0.062252  ...  1.402864e-16 -1.676307e-16
# 2  2.238317  0.208896 -1.608321  ... -3.203350e-16  4.618181e-16
# 3  2.377569  1.168006 -1.572199  ... -5.214706e-17 -1.133144e-16
# 4 -2.200951  1.201501 -1.852551  ...  4.806226e-16  1.523713e-16
#
#             240           241           242           243           244  \
# 0  4.205962e-16 -8.691376e-18 -2.613988e-16 -1.722563e-16  8.364086e-16
# 1  2.707868e-16  1.442709e-16 -1.724230e-16 -2.201656e-16 -2.627042e-16
# 2  8.253815e-16  4.619823e-16  8.164827e-17 -6.797216e-18  1.905207e-16
# 3 -1.800913e-16 -5.105007e-16  1.353171e-16  2.863394e-16 -5.075837e-16
# 4 -6.399283e-17  1.438454e-16 -1.274533e-16 -9.886382e-17 -3.605448e-16
#
#             245           246           247
# 0 -2.846229e-16 -1.703480e-16 -2.095634e-16
# 1  2.857227e-16  7.390968e-17  1.600279e-16
# 2  3.029634e-16  3.960326e-16  2.560199e-16
# 3 -2.409411e-16 -5.198902e-16 -2.851201e-16
# 4  3.223429e-16 -2.686701e-16 -1.981464e-16
#
# [5 rows x 248 columns]

# %%
pc_train1 = train_res_df.iloc[:,:80]
print(pc_train1.shape)
pc_train1.head()
# Out:
# (1095, 80)
#          0         1         2         3         4         5         6   \
# 0 -4.622960  1.161616 -0.252797 -1.672862  0.419907  0.980594 -2.242490
# 1  3.460182  3.193334 -1.538067  4.954354 -2.296506  0.362510  1.131920
# 2 -3.727533  0.948955 -0.117145  0.794336 -1.013626 -2.305109  0.072100
# 3 -2.256559  0.127604  0.189685 -0.391265 -0.363494 -3.290996  3.478400
# 4  0.161543 -5.091692  1.469638 -1.366211  0.164836 -1.560062 -1.082986
#
#          7         8         9   ...        70        71        72        73  \
# 0  0.237645  0.396260 -1.035301  ...  0.138666 -0.308900  0.389960 -0.118849
# 1 -1.122479 -0.440176  0.062252  ... -0.238987 -0.341045 -0.502188  0.115955
# 2  2.238317  0.208896 -1.608321  ... -0.562840  0.340594 -0.892724  0.170697
# 3  2.377569  1.168006 -1.572199  ... -1.605024  2.154660  1.541211  0.554874
# 4 -2.200951  1.201501 -1.852551  ... -0.649731 -1.267377  1.383861  0.444362
#
#          74        75        76        77        78        79
# 0  0.438211 -0.278563  0.107132 -0.458338  0.285253  0.356943
# 1  0.871620 -0.597209 -1.491280  0.247173  0.233910 -1.131874
# 2  0.020227  0.311635 -0.447642  0.027376 -0.414009 -0.029700
# 3  1.554105 -1.334064 -1.285356  0.041283  0.915574 -0.394873
# 4 -0.004712  0.975507  0.795394  0.796413 -0.254571 -0.820256
#
# [5 rows x 80 columns]

# %%
test_res_df = pd.DataFrame(x_test_pc1)
pc_test1 = test_res_df.iloc[:,:80]
print(pc_test1.shape)
pc_test1.head()
# Out:
# (365, 80)
#          0         1         2         3         4         5         6   \
# 0  1.163742 -4.973318  2.064422  0.576793  1.935019  1.702125 -0.095840
# 1 -4.986402  4.101710 -1.155137 -2.660450 -0.436282  3.628721 -0.644896
# 2  3.048258 -2.985700  0.088437 -1.661596 -0.042465  1.481756 -2.355095
# 3  0.287730 -3.827212  1.177659 -0.556239  0.426184 -0.521347 -1.034792
# 4 -5.780792  3.047428  0.179937  3.474932 -0.604579 -0.339707 -1.593825
#
#          7         8         9   ...        70        71        72        73  \
# 0 -0.931950 -0.768576  1.833031  ...  0.718719  2.282772 -0.378319 -0.025680
# 1  0.081258 -1.088594  3.242532  ... -0.652539 -0.130129 -0.011384  0.754219
# 2  0.738797 -0.245938 -0.650122  ...  0.184570 -0.230052 -0.381346  0.870068
# 3 -0.265599  0.345889  0.619083  ...  1.985976 -1.019392  1.151050 -1.455410
# 4 -1.066398 -0.650316 -0.013347  ...  1.382331  0.037547 -0.712485 -0.294459
#
#          74        75        76        77        78        79
# 0 -0.748730  0.271218 -0.240627 -0.555689  0.770248  0.638118
# 1 -0.528381  0.066935  0.408798 -0.011951 -0.331926 -0.860567
# 2  0.566271  0.277971  0.641269 -0.564385 -0.753599 -0.128855
# 3  0.260457 -1.064860  0.428149  0.892203 -1.821500  1.949897
# 4  0.442253  0.079272 -0.007594  0.224012 -0.549256  0.827346
#
# [5 rows x 80 columns]

# %%
print(pc_train1.shape)
print(pc_test1.shape)
print(y_train1.shape)
print(y_test1.shape)
# Out:
# (1095, 80)
# (365, 80)
# (1095,)
# (365,)

# %%
from sklearn.linear_model import LinearRegression

# %%
m5 = LinearRegression()
m5.fit(pc_train1,y_train1)
print('Training_score',m5.score(pc_train1,y_train1))
print('Testing_score',m5.score(pc_test1,y_test1))
# Out:
# Training_score 0.8828115298232833
# Testing_score 0.882979874437865

# %%
ypred_m5 = m5.predict(pc_test1)

# %%
gen_matrix(y_test1,ypred_m5)
# Out:
# MAE 18906.614838694808
# MSE 632663026.5847511
# RMSE 25152.793613925893
# R2_score 0.882979874437865

# %%
print(pc_train1.shape)
print(type(pc_train1))
# Out:
# (1095, 80)
# <class 'pandas.core.frame.DataFrame'>

# %%
t = []
s = 'PC'                             # PC = Principal component
for i in range(pc_train1.shape[1]):  # x_reg.shape =(1095, 80)  # i=0,1,2,3,.....,80
    d = s + str(i)
    t.append(d)
print(t)
# Out:
# ['PC0', 'PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9', 'PC10', 'PC11', 'PC12', 'PC13', 'PC14', 'PC15', 'PC16', 'PC17', 'PC18', 'PC19', 'PC20', 'PC21', 'PC22', 'PC23', 'PC24', 'PC25', 'PC26', 'PC27', 'PC28', 'PC29', 'PC30', 'PC31', 'PC32', 'PC33', 'PC34', 'PC35', 'PC36', 'PC37', 'PC38', 'PC39', 'PC40', 'PC41', 'PC42', 'PC43', 'PC44', 'PC45', 'PC46', 'PC47', 'PC48', 'PC49', 'PC50', 'PC51', 'PC52', 'PC53', 'PC54', 'PC55', 'PC56', 'PC57', 'PC58', 'PC59', 'PC60', 'PC61', 'PC62', 'PC63', 'PC64', 'PC65', 'PC66', 'PC67', 'PC68', 'PC69', 'PC70', 'PC71', 'PC72', 'PC73', 'PC74', 'PC75', 'PC76', 'PC77', 'PC78', 'PC79']

# %%
pc_train1.columns = t
pc_train1.head()
# Out:
#         PC0       PC1       PC2       PC3       PC4       PC5       PC6  \
# 0 -4.622960  1.161616 -0.252797 -1.672862  0.419907  0.980594 -2.242490
# 1  3.460182  3.193334 -1.538067  4.954354 -2.296506  0.362510  1.131920
# 2 -3.727533  0.948955 -0.117145  0.794336 -1.013626 -2.305109  0.072100
# 3 -2.256559  0.127604  0.189685 -0.391265 -0.363494 -3.290996  3.478400
# 4  0.161543 -5.091692  1.469638 -1.366211  0.164836 -1.560062 -1.082986
#
#         PC7       PC8       PC9  ...      PC70      PC71      PC72      PC73  \
# 0  0.237645  0.396260 -1.035301  ...  0.138666 -0.308900  0.389960 -0.118849
# 1 -1.122479 -0.440176  0.062252  ... -0.238987 -0.341045 -0.502188  0.115955
# 2  2.238317  0.208896 -1.608321  ... -0.562840  0.340594 -0.892724  0.170697
# 3  2.377569  1.168006 -1.572199  ... -1.605024  2.154660  1.541211  0.554874
# 4 -2.200951  1.201501 -1.852551  ... -0.649731 -1.267377  1.383861  0.444362
#
#        PC74      PC75      PC76      PC77      PC78      PC79
# 0  0.438211 -0.278563  0.107132 -0.458338  0.285253  0.356943
# 1  0.871620 -0.597209 -1.491280  0.247173  0.233910 -1.131874
# 2  0.020227  0.311635 -0.447642  0.027376 -0.414009 -0.029700
# 3  1.554105 -1.334064 -1.285356  0.041283  0.915574 -0.394873
# 4 -0.004712  0.975507  0.795394  0.796413 -0.254571 -0.820256
#
# [5 rows x 80 columns]

# %%
print(pc_test1.shape)
print(type(pc_test1))
# Out:
# (365, 80)
# <class 'pandas.core.frame.DataFrame'>

# %%
t1 = []
s = 'PC'                         # PC = Principal component
for i in range(pc_test1.shape[1]):  # pc_test1.shape =(365, 80)  # i=0,1,2,3,.....,80
    d = s + str(i)
    t1.append(d)
print(t1)
# Out:
# ['PC0', 'PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9', 'PC10', 'PC11', 'PC12', 'PC13', 'PC14', 'PC15', 'PC16', 'PC17', 'PC18', 'PC19', 'PC20', 'PC21', 'PC22', 'PC23', 'PC24', 'PC25', 'PC26', 'PC27', 'PC28', 'PC29', 'PC30', 'PC31', 'PC32', 'PC33', 'PC34', 'PC35', 'PC36', 'PC37', 'PC38', 'PC39', 'PC40', 'PC41', 'PC42', 'PC43', 'PC44', 'PC45', 'PC46', 'PC47', 'PC48', 'PC49', 'PC50', 'PC51', 'PC52', 'PC53', 'PC54', 'PC55', 'PC56', 'PC57', 'PC58', 'PC59', 'PC60', 'PC61', 'PC62', 'PC63', 'PC64', 'PC65', 'PC66', 'PC67', 'PC68', 'PC69', 'PC70', 'PC71', 'PC72', 'PC73', 'PC74', 'PC75', 'PC76', 'PC77', 'PC78', 'PC79']

# %%
pc_test1.columns = t1
pc_test1.head()
# Out:
#         PC0       PC1       PC2       PC3       PC4       PC5       PC6  \
# 0  1.163742 -4.973318  2.064422  0.576793  1.935019  1.702125 -0.095840
# 1 -4.986402  4.101710 -1.155137 -2.660450 -0.436282  3.628721 -0.644896
# 2  3.048258 -2.985700  0.088437 -1.661596 -0.042465  1.481756 -2.355095
# 3  0.287730 -3.827212  1.177659 -0.556239  0.426184 -0.521347 -1.034792
# 4 -5.780792  3.047428  0.179937  3.474932 -0.604579 -0.339707 -1.593825
#
#         PC7       PC8       PC9  ...      PC70      PC71      PC72      PC73  \
# 0 -0.931950 -0.768576  1.833031  ...  0.718719  2.282772 -0.378319 -0.025680
# 1  0.081258 -1.088594  3.242532  ... -0.652539 -0.130129 -0.011384  0.754219
# 2  0.738797 -0.245938 -0.650122  ...  0.184570 -0.230052 -0.381346  0.870068
# 3 -0.265599  0.345889  0.619083  ...  1.985976 -1.019392  1.151050 -1.455410
# 4 -1.066398 -0.650316 -0.013347  ...  1.382331  0.037547 -0.712485 -0.294459
#
#        PC74      PC75      PC76      PC77      PC78      PC79
# 0 -0.748730  0.271218 -0.240627 -0.555689  0.770248  0.638118
# 1 -0.528381  0.066935  0.408798 -0.011951 -0.331926 -0.860567
# 2  0.566271  0.277971  0.641269 -0.564385 -0.753599 -0.128855
# 3  0.260457 -1.064860  0.428149  0.892203 -1.821500  1.949897
# 4  0.442253  0.079272 -0.007594  0.224012 -0.549256  0.827346
#
# [5 rows x 80 columns]
